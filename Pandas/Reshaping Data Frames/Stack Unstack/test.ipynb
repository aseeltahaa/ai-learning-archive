# %%
import pandas as pd

# %%
df = pd.read_excel('stocks.xlsx', header = [0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df_stacked = df.stack()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7984\3205536143.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df.stack()

# %%
df.stack(level = 0)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7984\4254682145.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level = 0)
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
# ...

# %%
df_stacked.unstack()
# Out:
#   Unnamed: 0_level_0                             Price                   \
#              Company Facebook Google Microsoft Company Facebook  Google
# 0         2017-06-05      NaT    NaT       NaT     NaN    155.0   955.0
# 1         2017-06-06      NaT    NaT       NaT     NaN    150.0   987.0
# 2         2017-06-07      NaT    NaT       NaT     NaN    153.0   963.0
# 3         2017-06-08      NaT    NaT       NaT     NaN    155.0  1000.0
# 4         2017-06-09      NaT    NaT       NaT     NaN    156.0  1012.0
#
#             Price to earnings ratio (P/E)
#   Microsoft                       Company Facebook Google Microsoft
# 0      66.0                           NaN    37.10   32.0     30.31
# 1      69.0                           NaN    36.98   31.3     30.56
# 2      62.0                           NaN    36.78   31.7     30.46
# 3      61.0                           NaN    36.11   31.2     30.11
# 4      66.0                           NaN    37.07   30.0     31.00

# %%
df2 = pd.read_excel('stocks_3_levels.xlsx', header = [0,1])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                     \
#   Unnamed: 0_level_1        Price Price.1    Price.2
# 0            Company     Facebook  Google  Microsoft
# 1            Q1 2016          155     955         66
# 2            Q2 2016          150     987         69
# 3            Q3 2016          153     963         62
# 4            Q4 2016          155    1000         61
# 5            Q1 2017          156    1012         66
#
#                                                                  \
#   Price to earnings ratio (P/E) Price to earnings ratio (P/E).1
# 0                      Facebook                          Google
# 1                          37.1                              32
# 2                         36.98                            31.3
# 3                         36.78                            31.7
# 4                         36.11                            31.2
# 5                         37.07                              30
#
# ...

# %%
df2.stack(level = 0)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7984\2500371938.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2.stack(level = 0)
#                      Unnamed: 0_level_1     Price Price.1    Price.2  \
# 0 Income Statement                  NaN       NaN     NaN        NaN
#   Price Ratios                      NaN  Facebook  Google  Microsoft
#   Unnamed: 0_level_0            Company       NaN     NaN        NaN
# 1 Income Statement                  NaN       NaN     NaN        NaN
#   Price Ratios                      NaN       155     955         66
#   Unnamed: 0_level_0            Q1 2016       NaN     NaN        NaN
# 2 Income Statement                  NaN       NaN     NaN        NaN
#   Price Ratios                      NaN       150     987         69
# ...

# %%
df2.stack(level = 1)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7984\1587966785.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2.stack(level = 1)
#                                   Unnamed: 0_level_0 Price Ratios  \
# 0 Net Profit                                     NaN          NaN
#   Net Profit.1                                   NaN          NaN
#   Net Profit.2                                   NaN          NaN
#   Net Sales                                      NaN          NaN
#   Net Sales.1                                    NaN          NaN
# ...                                              ...          ...
# 5 Price to earnings ratio (P/E).1                NaN           30
#   Price to earnings ratio (P/E).2                NaN           31
# ...

# %%
df.level =
